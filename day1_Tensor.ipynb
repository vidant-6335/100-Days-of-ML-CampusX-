# %%
import numpy as np

# %%
# 0D tensor
a = np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
# 1D tensor
arr = np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
arr.ndim
# Out:
# 1

# %%
# 2D tensor
arr1 = np.array([[1,2], [3,4]])
arr1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr1.ndim
# Out:
# 2
